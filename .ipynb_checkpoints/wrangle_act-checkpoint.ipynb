# %% [markdown]
# # Data Wrangling Project (WeRateDogs)
# ## By Zakarea Sabi

# %% [markdown]
# ## Gather

# %%
import pandas as pd
import numpy as np
import requests
import tweepy
import re
import os
import json
import time
import warnings
import matplotlib.pyplot as plt

# %% [markdown]
# ### Twitter archive

# %%
twitter_archive = pd.read_csv('twitter-archive-enhanced.csv')

# %%
twitter_archive.head()
# Out:
#              tweet_id  in_reply_to_status_id  in_reply_to_user_id  \
# 0  892420643555336193                    NaN                  NaN
# 1  892177421306343426                    NaN                  NaN
# 2  891815181378084864                    NaN                  NaN
# 3  891689557279858688                    NaN                  NaN
# 4  891327558926688256                    NaN                  NaN
#
#                    timestamp  \
# 0  2017-08-01 16:23:56 +0000
# 1  2017-08-01 00:17:27 +0000
# 2  2017-07-31 00:18:03 +0000
# 3  2017-07-30 15:58:51 +0000
# 4  2017-07-29 16:00:24 +0000
#
#                                               source  \
# 0  <a href="http://twitter.com/download/iphone" r...
# 1  <a href="http://twitter.com/download/iphone" r...
# 2  <a href="http://twitter.com/download/iphone" r...
# 3  <a href="http://twitter.com/download/iphone" r...
# 4  <a href="http://twitter.com/download/iphone" r...
#
#                                                 text  retweeted_status_id  \
# 0  This is Phineas. He's a mystical boy. Only eve...                  NaN
# 1  This is Tilly. She's just checking pup on you....                  NaN
# 2  This is Archie. He is a rare Norwegian Pouncin...                  NaN
# 3  This is Darla. She commenced a snooze mid meal...                  NaN
# 4  This is Franklin. He would like you to stop ca...                  NaN
#
#    retweeted_status_user_id retweeted_status_timestamp  \
# 0                       NaN                        NaN
# 1                       NaN                        NaN
# 2                       NaN                        NaN
# 3                       NaN                        NaN
# 4                       NaN                        NaN
#
#                                        expanded_urls  rating_numerator  \
# 0  https://twitter.com/dog_rates/status/892420643...                13
# 1  https://twitter.com/dog_rates/status/892177421...                13
# 2  https://twitter.com/dog_rates/status/891815181...                12
# 3  https://twitter.com/dog_rates/status/891689557...                13
# 4  https://twitter.com/dog_rates/status/891327558...                12
#
#    rating_denominator      name doggo floofer pupper puppo
# 0                  10   Phineas  None    None   None  None
# 1                  10     Tilly  None    None   None  None
# 2                  10    Archie  None    None   None  None
# 3                  10     Darla  None    None   None  None
# 4                  10  Franklin  None    None   None  None

# %%
twitter_archive.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2356 entries, 0 to 2355
# Data columns (total 17 columns):
# tweet_id                      2356 non-null int64
# in_reply_to_status_id         78 non-null float64
# in_reply_to_user_id           78 non-null float64
# timestamp                     2356 non-null object
# source                        2356 non-null object
# text                          2356 non-null object
# retweeted_status_id           181 non-null float64
# retweeted_status_user_id      181 non-null float64
# retweeted_status_timestamp    181 non-null object
# expanded_urls                 2297 non-null object
# rating_numerator              2356 non-null int64
# rating_denominator            2356 non-null int64
# name                          2356 non-null object
# doggo                         2356 non-null object
# floofer                       2356 non-null object
# pupper                        2356 non-null object
# puppo                         2356 non-null object
# dtypes: float64(4), int64(3), object(10)
# memory usage: 313.0+ KB

# %% [markdown]
# ### Image predictions

# %%
# get file with the image predictions
url = 'https://d17h27t6h515a5.cloudfront.net/topher/2017/August/599fd2ad_image-predictions/image-predictions.tsv'
with open('image-predictions.tsv' , 'wb') as file:
    predictions = requests.get(url)
    file.write(predictions.content)

# load image predictions
image_prediction = pd.read_csv('image-predictions.tsv', sep = '\t')
# display few lines
image_prediction.head()
# Out:
#              tweet_id                                          jpg_url  \
# 0  666020888022790149  https://pbs.twimg.com/media/CT4udn0WwAA0aMy.jpg
# 1  666029285002620928  https://pbs.twimg.com/media/CT42GRgUYAA5iDo.jpg
# 2  666033412701032449  https://pbs.twimg.com/media/CT4521TWwAEvMyu.jpg
# 3  666044226329800704  https://pbs.twimg.com/media/CT5Dr8HUEAA-lEu.jpg
# 4  666049248165822465  https://pbs.twimg.com/media/CT5IQmsXIAAKY4A.jpg
#
#    img_num                      p1   p1_conf  p1_dog                  p2  \
# 0        1  Welsh_springer_spaniel  0.465074    True              collie
# 1        1                 redbone  0.506826    True  miniature_pinscher
# 2        1         German_shepherd  0.596461    True            malinois
# 3        1     Rhodesian_ridgeback  0.408143    True             redbone
# 4        1      miniature_pinscher  0.560311    True          Rottweiler
#
#     p2_conf  p2_dog                   p3   p3_conf  p3_dog
# 0  0.156665    True    Shetland_sheepdog  0.061428    True
# 1  0.074192    True  Rhodesian_ridgeback  0.072010    True
# 2  0.138584    True           bloodhound  0.116197    True
# 3  0.360687    True   miniature_pinscher  0.222752    True
# 4  0.243682    True             Doberman  0.154629    True

# %%
image_prediction.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2075 entries, 0 to 2074
# Data columns (total 12 columns):
# tweet_id    2075 non-null int64
# jpg_url     2075 non-null object
# img_num     2075 non-null int64
# p1          2075 non-null object
# p1_conf     2075 non-null float64
# p1_dog      2075 non-null bool
# p2          2075 non-null object
# p2_conf     2075 non-null float64
# p2_dog      2075 non-null bool
# p3          2075 non-null object
# p3_conf     2075 non-null float64
# p3_dog      2075 non-null bool
# dtypes: bool(3), float64(3), int64(2), object(4)
# memory usage: 152.1+ KB

# %% [markdown]
# ##  Twitter API

# %%
with open('tweet-json.txt') as f:
    twitter_api = pd.DataFrame((json.loads(line) for line in f), columns = ['id', 'favorite_count', 'retweet_count'])

twitter_api.columns = ['tweet_id', 'favorites', 'retweets']

twitter_api.head()
# Out:
#              tweet_id  favorites  retweets
# 0  892420643555336193      39467      8853
# 1  892177421306343426      33819      6514
# 2  891815181378084864      25461      4328
# 3  891689557279858688      42908      8964
# 4  891327558926688256      41048      9774

# %% [markdown]
# ## Assess

# %% [markdown]
# ### twitter_archive

# %%
twitter_archive.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2356 entries, 0 to 2355
# Data columns (total 17 columns):
# tweet_id                      2356 non-null int64
# in_reply_to_status_id         78 non-null float64
# in_reply_to_user_id           78 non-null float64
# timestamp                     2356 non-null object
# source                        2356 non-null object
# text                          2356 non-null object
# retweeted_status_id           181 non-null float64
# retweeted_status_user_id      181 non-null float64
# retweeted_status_timestamp    181 non-null object
# expanded_urls                 2297 non-null object
# rating_numerator              2356 non-null int64
# rating_denominator            2356 non-null int64
# name                          2356 non-null object
# doggo                         2356 non-null object
# floofer                       2356 non-null object
# pupper                        2356 non-null object
# puppo                         2356 non-null object
# dtypes: float64(4), int64(3), object(10)
# memory usage: 313.0+ KB

# %%
twitter_archive.sample(10)
# Out:
#                 tweet_id  in_reply_to_status_id  in_reply_to_user_id  \
# 538   806620845233815552                    NaN                  NaN
# 1652  683481228088049664                    NaN                  NaN
# 515   811386762094317568                    NaN                  NaN
# 434   820494788566847489                    NaN                  NaN
# 1406  699088579889332224                    NaN                  NaN
# 51    882268110199369728                    NaN                  NaN
# 1573  687494652870668288                    NaN                  NaN
# 2074  670842764863651840                    NaN                  NaN
# 2035  671735591348891648                    NaN                  NaN
# 757   778624900596654080                    NaN                  NaN
#
#                       timestamp  \
# 538   2016-12-07 22:06:10 +0000
# 1652  2016-01-03 02:53:17 +0000
# 515   2016-12-21 01:44:13 +0000
# 434   2017-01-15 04:56:16 +0000
# 1406  2016-02-15 04:31:20 +0000
# 51    2017-07-04 16:01:23 +0000
# 1573  2016-01-14 04:41:12 +0000
# 2074  2015-11-29 05:52:33 +0000
# 2035  2015-12-01 17:00:19 +0000
# 757   2016-09-21 16:00:17 +0000
#
#                                                  source  \
# 538   <a href="http://twitter.com/download/iphone" r...
# 1652  <a href="http://twitter.com/download/iphone" r...
# 515   <a href="http://twitter.com/download/iphone" r...
# 434   <a href="http://twitter.com/download/iphone" r...
# 1406  <a href="http://twitter.com/download/iphone" r...
# 51    <a href="http://twitter.com/download/iphone" r...
# 1573  <a href="http://twitter.com/download/iphone" r...
# 2074  <a href="http://twitter.com/download/iphone" r...
# 2035  <a href="http://twitter.com/download/iphone" r...
# 757   <a href="http://twitter.com/download/iphone" r...
#
#                                                    text  retweeted_status_id  \
# 538   RT @dog_rates: Idk why this keeps happening. W...         7.815247e+17
# 1652  Meet Banjo. He's a Peppercorn Shoop Da Whoop. ...                  NaN
# 515   This is Craig. That's actually a normal sized ...                  NaN
# 434   RT @dog_rates: We are proud to support @LoveYo...         8.203146e+17
# 1406  This is Charl. He's a bully. Chucks that dumbb...                  NaN
# 51    This is Alfy. You're witnessing his first wate...                  NaN
# 1573  This is Marq. He stole this car. 7/10 wtf Marq...                  NaN
# 2074  After so many requests... here you go.\n\nGood...                  NaN
# 2035  This is Oscar. He's ready for Christmas. 11/10...                  NaN
# 757   This is Penny. She's a sailor pup. 11/10 would...                  NaN
#
#       retweeted_status_user_id retweeted_status_timestamp  \
# 538               4.196984e+09  2016-09-29 16:03:01 +0000
# 1652                       NaN                        NaN
# 515                        NaN                        NaN
# 434               4.196984e+09  2017-01-14 17:00:24 +0000
# 1406                       NaN                        NaN
# 51                         NaN                        NaN
# 1573                       NaN                        NaN
# 2074                       NaN                        NaN
# 2035                       NaN                        NaN
# 757                        NaN                        NaN
#
#                                           expanded_urls  rating_numerator  \
# 538   https://twitter.com/dog_rates/status/781524693...                12
# 1652  https://twitter.com/dog_rates/status/683481228...                11
# 515   https://twitter.com/dog_rates/status/811386762...                11
# 434   https://www.loveyourmelon.com/pages/ourstory,h...                14
# 1406  https://twitter.com/dog_rates/status/699088579...                 3
# 51    https://twitter.com/dog_rates/status/882268110...                13
# 1573  https://twitter.com/dog_rates/status/687494652...                 7
# 2074  https://twitter.com/dog_rates/status/670842764...               420
# 2035  https://twitter.com/dog_rates/status/671735591...                11
# 757   https://twitter.com/dog_rates/status/778624900...                11
#
#       rating_denominator   name doggo floofer  pupper puppo
# 538                   10   None  None    None    None  None
# 1652                  10  Banjo  None    None  pupper  None
# 515                   10  Craig  None    None  pupper  None
# 434                   10   None  None    None    None  None
# 1406                  10  Charl  None    None    None  None
# 51                    10   Alfy  None    None    None  None
# 1573                  10   Marq  None    None    None  None
# 2074                  10   None  None    None    None  None
# 2035                  10  Oscar  None    None    None  None
# 757                   10  Penny  None    None    None  None

# %%
twitter_archive.describe()
# Out:
#            tweet_id  in_reply_to_status_id  in_reply_to_user_id  \
# count  2.356000e+03           7.800000e+01         7.800000e+01
# mean   7.427716e+17           7.455079e+17         2.014171e+16
# std    6.856705e+16           7.582492e+16         1.252797e+17
# min    6.660209e+17           6.658147e+17         1.185634e+07
# 25%    6.783989e+17           6.757419e+17         3.086374e+08
# 50%    7.196279e+17           7.038708e+17         4.196984e+09
# 75%    7.993373e+17           8.257804e+17         4.196984e+09
# max    8.924206e+17           8.862664e+17         8.405479e+17
#
#        retweeted_status_id  retweeted_status_user_id  rating_numerator  \
# count         1.810000e+02              1.810000e+02       2356.000000
# mean          7.720400e+17              1.241698e+16         13.126486
# std           6.236928e+16              9.599254e+16         45.876648
# min           6.661041e+17              7.832140e+05          0.000000
# 25%           7.186315e+17              4.196984e+09         10.000000
# 50%           7.804657e+17              4.196984e+09         11.000000
# 75%           8.203146e+17              4.196984e+09         12.000000
# max           8.874740e+17              7.874618e+17       1776.000000
#
#        rating_denominator
# count         2356.000000
# mean            10.455433
# std              6.745237
# min              0.000000
# 25%             10.000000
# 50%             10.000000
# 75%             10.000000
# max            170.000000

# %%
twitter_archive['name']
# Out:
# 0        Phineas
# 1          Tilly
# 2         Archie
# 3          Darla
# 4       Franklin
#           ...
# 2351        None
# 2352           a
# 2353           a
# 2354           a
# 2355        None
# Name: name, Length: 2356, dtype: object

# %%
#because always none name words begain with small letter
#I used find lowercase way
none_sense = []
for row in twitter_archive['name']:
    if row[0].islower() and row not in none_sense:
        none_sense.append(row)
print(none_sense)
# Out:
# ['such', 'a', 'quite', 'not', 'one', 'incredibly', 'mad', 'an', 'very', 'just', 'my', 'his', 'actually', 'getting', 'this', 'unacceptable', 'all', 'old', 'infuriating', 'the', 'by', 'officially', 'life', 'light', 'space']

# %%
twitter_archive['name'].value_counts()
# Out:
# None        745
# a            55
# Charlie      12
# Cooper       11
# Lucy         11
#            ...
# Tiger         1
# Filup         1
# Zara          1
# Toffee        1
# Dietrich      1
# Name: name, Length: 957, dtype: int64

# %%
twitter_archive['name'].value_counts()
# Out:
# None        745
# a            55
# Charlie      12
# Cooper       11
# Lucy         11
#            ...
# Tiger         1
# Filup         1
# Zara          1
# Toffee        1
# Dietrich      1
# Name: name, Length: 957, dtype: int64

# %%
twitter_archive['doggo'].value_counts()
# Out:
# None     2259
# doggo      97
# Name: doggo, dtype: int64

# %%
twitter_archive['floofer'].value_counts()
# Out:
# None       2346
# floofer      10
# Name: floofer, dtype: int64

# %%
twitter_archive['puppo'].value_counts()
# Out:
# None     2326
# puppo      30
# Name: puppo, dtype: int64

# %%
twitter_archive['pupper'].value_counts()
# Out:
# None      2099
# pupper     257
# Name: pupper, dtype: int64

# %%
sum(twitter_archive['tweet_id'].duplicated())
# Out:
# 0

# %%
twitter_archive['text'].value_counts()
# Out:
# Here we see a Byzantine Rigatoni. Very aerodynamic. No eyes. Actually not windy here they just look like that. 9/10 https://t.co/gzI0m6wXRo                          1
# We only rate dogs. Pls stop sending in non-canines like this Urban Floof Giraffe. I can't handle this. 11/10 https://t.co/zHIqpM5Gni                                 1
# Please don't send in photos without dogs in them. We're not @porch_rates. Insubordinate and churlish. Pretty good porch tho 11/10 https://t.co/HauE8M3Bu4            1
# RT until we find this dog. Clearly a cool dog (front leg relaxed out window). Looks to be a superb driver. 10/10 https://t.co/MnTrKaQ8Wn                             1
# This is Brockly. He's an uber driver. Falls asleep at the wheel often. Irresponsible af 8/10 would totally still pet https://t.co/fn1oUlS69Z                         1
#                                                                                                                                                                     ..
# Here we have a northern speckled Rhododendron. Much sass. Gives 0 fucks. Good tongue. 9/10 would caress sensually https://t.co/ZoL8kq2XFx                            1
# This is Eli. He can fly. 13/10 magical af https://t.co/huPSJJ7FDI                                                                                                    1
# This is Sophie. She's a Jubilant Bush Pupper. Super h*ckin rare. Appears at random just to smile at the locals. 11.27/10 would smile back https://t.co/QFaUiIHxHq    1
# This is Jerry. He's a great listener. Low maintenance. Hard to get leash on tho. 8/10 still good dog https://t.co/NsDIt8Z80Z                                         1
# Say hello to Geoff (pronounced "Kyle"). He accidentally opened the front facing camera. 10/10 https://t.co/TmlwQWnmRC                                                1
# Name: text, Length: 2356, dtype: int64

# %% [markdown]
# Image predction

# %%
image_prediction
# Out:
#                 tweet_id                                          jpg_url  \
# 0     666020888022790149  https://pbs.twimg.com/media/CT4udn0WwAA0aMy.jpg
# 1     666029285002620928  https://pbs.twimg.com/media/CT42GRgUYAA5iDo.jpg
# 2     666033412701032449  https://pbs.twimg.com/media/CT4521TWwAEvMyu.jpg
# 3     666044226329800704  https://pbs.twimg.com/media/CT5Dr8HUEAA-lEu.jpg
# 4     666049248165822465  https://pbs.twimg.com/media/CT5IQmsXIAAKY4A.jpg
# ...                  ...                                              ...
# 2070  891327558926688256  https://pbs.twimg.com/media/DF6hr6BUMAAzZgT.jpg
# 2071  891689557279858688  https://pbs.twimg.com/media/DF_q7IAWsAEuuN8.jpg
# 2072  891815181378084864  https://pbs.twimg.com/media/DGBdLU1WsAANxJ9.jpg
# 2073  892177421306343426  https://pbs.twimg.com/media/DGGmoV4XsAAUL6n.jpg
# 2074  892420643555336193  https://pbs.twimg.com/media/DGKD1-bXoAAIAUK.jpg
#
#       img_num                      p1   p1_conf  p1_dog                  p2  \
# 0           1  Welsh_springer_spaniel  0.465074    True              collie
# 1           1                 redbone  0.506826    True  miniature_pinscher
# 2           1         German_shepherd  0.596461    True            malinois
# 3           1     Rhodesian_ridgeback  0.408143    True             redbone
# 4           1      miniature_pinscher  0.560311    True          Rottweiler
# ...       ...                     ...       ...     ...                 ...
# 2070        2                  basset  0.555712    True    English_springer
# 2071        1             paper_towel  0.170278   False  Labrador_retriever
# 2072        1               Chihuahua  0.716012    True            malamute
# 2073        1               Chihuahua  0.323581    True            Pekinese
# 2074        1                  orange  0.097049   False               bagel
#
#        p2_conf  p2_dog                           p3   p3_conf  p3_dog
# 0     0.156665    True            Shetland_sheepdog  0.061428    True
# 1     0.074192    True          Rhodesian_ridgeback  0.072010    True
# 2     0.138584    True                   bloodhound  0.116197    True
# 3     0.360687    True           miniature_pinscher  0.222752    True
# 4     0.243682    True                     Doberman  0.154629    True
# ...        ...     ...                          ...       ...     ...
# 2070  0.225770    True  German_short-haired_pointer  0.175219    True
# 2071  0.168086    True                      spatula  0.040836   False
# 2072  0.078253    True                       kelpie  0.031379    True
# 2073  0.090647    True                     papillon  0.068957    True
# 2074  0.085851   False                       banana  0.076110   False
#
# [2075 rows x 12 columns]

# %%
image_prediction.sample(10)
# Out:
#                 tweet_id                                            jpg_url  \
# 1454  777189768882946048    https://pbs.twimg.com/media/Cskh9nRWYAAUxBP.jpg
# 1588  798340744599797760    https://pbs.twimg.com/media/CrXhIqBW8AA6Bse.jpg
# 912   700847567345688576    https://pbs.twimg.com/media/CbnpI_1XIAAiRAz.jpg
# 108   667878741721415682    https://pbs.twimg.com/media/CUTILFiWcAE8Rle.jpg
# 225   670338931251150849    https://pbs.twimg.com/media/CU2FsRnVAAA3TEg.jpg
# 374   672995267319328768    https://pbs.twimg.com/media/CVb1mRiWcAADBsE.jpg
# 1254  748324050481647620    https://pbs.twimg.com/media/CmKUwImXIAA58f5.jpg
# 115   667937095915278337    https://pbs.twimg.com/media/CUT9PuQWwAABQv7.jpg
# 1155  733109485275860992    https://pbs.twimg.com/media/CiyHLocU4AI2pJu.jpg
# 1173  737310737551491075  https://pbs.twimg.com/ext_tw_video_thumb/73731...
#
#       img_num                   p1   p1_conf  p1_dog  \
# 1454        2            Chihuahua  0.988412    True
# 1588        1             papillon  0.533180    True
# 912         1  Rhodesian_ridgeback  0.252514    True
# 108         1            seat_belt  0.200373   False
# 225         1                cairn  0.245033    True
# 374         1       French_bulldog  0.719559    True
# 1254        1    Shetland_sheepdog  0.880499    True
# 115         1              hamster  0.172078   False
# 1155        1     golden_retriever  0.945523    True
# 1173        1                cliff  0.439077   False
#
#                                p2   p2_conf  p2_dog                   p3  \
# 1454             Mexican_hairless  0.004177    True                  hog
# 1588                       collie  0.192031    True        Border_collie
# 912                       redbone  0.153005    True              whippet
# 108            miniature_pinscher  0.106003    True           schipperke
# 225   West_Highland_white_terrier  0.137709    True  miniature_schnauzer
# 374                         boxer  0.166927    True          Boston_bull
# 1254                       collie  0.107901    True             Pembroke
# 115                    guinea_pig  0.094924   False             Band_Aid
# 1155           Labrador_retriever  0.042319    True              doormat
# 1173                     lakeside  0.062899   False               valley
#
#        p3_conf  p3_dog
# 1454  0.001507   False
# 1588  0.121626    True
# 912   0.135199    True
# 108   0.104733    True
# 225   0.089173    True
# 374   0.101354    True
# 1254  0.003607    True
# 115   0.059995   False
# 1155  0.003956   False
# 1173  0.039759   False

# %%
image_prediction.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2075 entries, 0 to 2074
# Data columns (total 12 columns):
# tweet_id    2075 non-null int64
# jpg_url     2075 non-null object
# img_num     2075 non-null int64
# p1          2075 non-null object
# p1_conf     2075 non-null float64
# p1_dog      2075 non-null bool
# p2          2075 non-null object
# p2_conf     2075 non-null float64
# p2_dog      2075 non-null bool
# p3          2075 non-null object
# p3_conf     2075 non-null float64
# p3_dog      2075 non-null bool
# dtypes: bool(3), float64(3), int64(2), object(4)
# memory usage: 152.1+ KB

# %%
sum(image_prediction.jpg_url.duplicated())
# Out:
# 66

# %%
sum(image_prediction['tweet_id'].duplicated())
# Out:
# 0

# %% [markdown]
# ## twitter_api

# %%
twitter_api.sample(10)
# Out:
#                 tweet_id  favorites  retweets
# 189   855857698524602368      12498      2313
# 1527  690248561355657216       1845       477
# 1277  708845821941387268       3226      1015
# 1045  743510151680958465       8671      4185
# 526   808733504066486276       8784      2509
# 2231  668204964695683073        586       206
# 385   826615380357632002          0      4521
# 1027  745712589599014916       7652      2636
# 498   813127251579564032      13242      3652
# 509   812372279581671427      15224      4252

# %%
twitter_api.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2354 entries, 0 to 2353
# Data columns (total 3 columns):
# tweet_id     2354 non-null int64
# favorites    2354 non-null int64
# retweets     2354 non-null int64
# dtypes: int64(3)
# memory usage: 55.3 KB

# %%
sum(twitter_api['tweet_id'].duplicated())
# Out:
# 0

# %% [markdown]
# ## Issues in twitter_archive:
#     1-retweeted_status_timestamp is type 'object'
#     2-doggo, floofer, pupper, puppo have string none value it should be NaN
#     3- there are a lot of names that dont make sense such as 'a', 'all', 'old', 'infuriating', 'the' also 'None'
#     I noticed that programticaly also I have noticed that by MS Excel i found 'not' , 'an'
#     4-tweet id need to be string

# %% [markdown]
# ## Clean
# #### Code

# %%
#solution for issue (1)
twitter_archive['timestamp'] = pd.to_datetime(twitter_archive['timestamp'], format = "%Y-%m-%d %H:%M:%S")

# %%
#solution for issue (2)
twitter_archive['doggo'].replace('None', 
                        np.nan,
                       inplace = True)
twitter_archive['floofer'].replace('None', 
                        np.nan,
                       inplace = True)
twitter_archive['pupper'].replace('None', 
                        np.nan,
                       inplace = True)
twitter_archive['puppo'].replace('None', 
                        np.nan,
                       inplace = True)

# %%
#solution for issue (3) replace it by Nan
twitter_archive['name'].replace(none_sense, 
                        np.nan,
                       inplace = True)
twitter_archive['name'].replace('None', 
                        np.nan,
                       inplace = True)

# %%
#solutiion for issue 4
twitter_archive['tweet_id'] =  twitter_archive['tweet_id'].astype(str)

# %% [markdown]
# ## Test twitter_archive

# %%
twitter_archive.sample(10)
# Out:
#                 tweet_id  in_reply_to_status_id  in_reply_to_user_id  \
# 1933  674019345211760640                    NaN                  NaN
# 413   822872901745569793                    NaN                  NaN
# 47    883117836046086144                    NaN                  NaN
# 2004  672466075045466113                    NaN                  NaN
# 2074  670842764863651840                    NaN                  NaN
# 1269  709519240576036864                    NaN                  NaN
# 906   758041019896193024                    NaN                  NaN
# 609   797545162159308800                    NaN                  NaN
# 652   792394556390137856                    NaN                  NaN
# 281   839290600511926273                    NaN                  NaN
#
#                      timestamp  \
# 1933 2015-12-08 00:15:09+00:00
# 413  2017-01-21 18:26:02+00:00
# 47   2017-07-07 00:17:54+00:00
# 2004 2015-12-03 17:23:00+00:00
# 2074 2015-11-29 05:52:33+00:00
# 1269 2016-03-14 23:19:03+00:00
# 906  2016-07-26 20:47:17+00:00
# 609  2016-11-12 21:02:38+00:00
# 652  2016-10-29 15:55:58+00:00
# 281  2017-03-08 01:44:07+00:00
#
#                                                  source  \
# 1933  <a href="http://twitter.com/download/iphone" r...
# 413   <a href="http://twitter.com/download/iphone" r...
# 47    <a href="http://twitter.com/download/iphone" r...
# 2004  <a href="http://twitter.com/download/iphone" r...
# 2074  <a href="http://twitter.com/download/iphone" r...
# 1269  <a href="http://twitter.com/download/iphone" r...
# 906   <a href="http://twitter.com/download/iphone" r...
# 609   <a href="http://twitter.com/download/iphone" r...
# 652   <a href="http://twitter.com/download/iphone" r...
# 281   <a href="http://twitter.com/download/iphone" r...
#
#                                                    text  retweeted_status_id  \
# 1933  This is Acro. You briefly see her out of the c...                  NaN
# 413   Here's a super supportive puppo participating ...                  NaN
# 47    Please only send dogs. We don't rate mechanics...                  NaN
# 2004  This is Franq and Pablo. They're working hard ...                  NaN
# 2074  After so many requests... here you go.\n\nGood...                  NaN
# 1269  This is Vince. He's a Gregorian Flapjeck. Whit...                  NaN
# 906   Teagan reads entire books in store so they're ...                  NaN
# 609   This is Cassie. She steals things. Guilt incre...                  NaN
# 652   Meet BeBe. She rocks the messy bun of your dre...                  NaN
# 281   RT @alexmartindawg: THE DRINK IS DR. PUPPER 10...         8.392899e+17
#
#       retweeted_status_user_id retweeted_status_timestamp  \
# 1933                       NaN                        NaN
# 413                        NaN                        NaN
# 47                         NaN                        NaN
# 2004                       NaN                        NaN
# 2074                       NaN                        NaN
# 1269                       NaN                        NaN
# 906                        NaN                        NaN
# 609                        NaN                        NaN
# 652                        NaN                        NaN
# 281                 41198418.0  2017-03-08 01:41:24 +0000
#
#                                           expanded_urls  rating_numerator  \
# 1933  https://twitter.com/dog_rates/status/674019345...                10
# 413   https://twitter.com/dog_rates/status/822872901...                13
# 47    https://twitter.com/dog_rates/status/883117836...                13
# 2004  https://twitter.com/dog_rates/status/672466075...                12
# 2074  https://twitter.com/dog_rates/status/670842764...               420
# 1269  https://twitter.com/dog_rates/status/709519240...                 9
# 906   https://twitter.com/dog_rates/status/758041019...                 9
# 609   https://twitter.com/dog_rates/status/797545162...                12
# 652   https://twitter.com/dog_rates/status/792394556...                12
# 281   https://twitter.com/alexmartindawg/status/8392...                10
#
#       rating_denominator    name doggo floofer  pupper  puppo
# 1933                  10    Acro   NaN     NaN     NaN    NaN
# 413                   10     NaN   NaN     NaN     NaN  puppo
# 47                    10     NaN   NaN     NaN     NaN    NaN
# 2004                  10   Franq   NaN     NaN     NaN    NaN
# 2074                  10     NaN   NaN     NaN     NaN    NaN
# 1269                  10   Vince   NaN     NaN     NaN    NaN
# 906                   10     NaN   NaN     NaN     NaN    NaN
# 609                   10  Cassie   NaN     NaN     NaN    NaN
# 652                   10    BeBe   NaN     NaN     NaN    NaN
# 281                   10     NaN   NaN     NaN  pupper    NaN

# %%
twitter_archive['name'].value_counts()
# Out:
# Charlie    12
# Oliver     11
# Lucy       11
# Cooper     11
# Penny      10
#            ..
# Mimosa      1
# Batdog      1
# Willem      1
# Trigger     1
# Jett        1
# Name: name, Length: 931, dtype: int64

# %%
twitter_archive['name']
# Out:
# 0        Phineas
# 1          Tilly
# 2         Archie
# 3          Darla
# 4       Franklin
#           ...
# 2351         NaN
# 2352         NaN
# 2353         NaN
# 2354         NaN
# 2355         NaN
# Name: name, Length: 2356, dtype: object

# %%
twitter_archive.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2356 entries, 0 to 2355
# Data columns (total 17 columns):
# tweet_id                      2356 non-null object
# in_reply_to_status_id         78 non-null float64
# in_reply_to_user_id           78 non-null float64
# timestamp                     2356 non-null datetime64[ns, UTC]
# source                        2356 non-null object
# text                          2356 non-null object
# retweeted_status_id           181 non-null float64
# retweeted_status_user_id      181 non-null float64
# retweeted_status_timestamp    181 non-null object
# expanded_urls                 2297 non-null object
# rating_numerator              2356 non-null int64
# rating_denominator            2356 non-null int64
# name                          1502 non-null object
# doggo                         97 non-null object
# floofer                       10 non-null object
# pupper                        257 non-null object
# puppo                         30 non-null object
# dtypes: datetime64[ns, UTC](1), float64(4), int64(2), object(10)
# memory usage: 313.0+ KB

# %% [markdown]
# ## issues in  Image predictions:

# %% [markdown]
# 1-there are 66 dublicated urls
#
# 2-Image predictions dataset should be emerged with twitter_archive
# 3- tweet id need change it to string
#
# 4- create new culomns named dog_types

# %%
image_prediction = image_prediction.drop_duplicates()
image_prediction['tweet_id'] =  image_prediction['tweet_id'].astype(str)
dog_types = []

def image(image_prediction):
    if image_prediction['p1_dog'] == True:
        dog_types.append(image_prediction['p1'])
    elif image_prediction['p2_dog'] == True:
        dog_types.append(image_prediction['p2'])
    elif image_prediction['p3_dog'] == True:
        dog_types.append(image_prediction['p3'])     
    else:
        dog_types.append('none')

image_prediction.apply(image, axis=1)

image_prediction['dog_types'] = dog_types

# %% [markdown]
# ### test Image predictions

# %%
sum(image_prediction.jpg_url.duplicated())
image_prediction.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 2075 entries, 0 to 2074
# Data columns (total 13 columns):
# tweet_id     2075 non-null object
# jpg_url      2075 non-null object
# img_num      2075 non-null int64
# p1           2075 non-null object
# p1_conf      2075 non-null float64
# p1_dog       2075 non-null bool
# p2           2075 non-null object
# p2_conf      2075 non-null float64
# p2_dog       2075 non-null bool
# p3           2075 non-null object
# p3_conf      2075 non-null float64
# p3_dog       2075 non-null bool
# dog_types    2075 non-null object
# dtypes: bool(3), float64(3), int64(1), object(6)
# memory usage: 184.4+ KB

# %% [markdown]
# ### issues in twitter_api:
# 1- tweet_id should be string to merge it with the others

# %%
 twitter_api['tweet_id'] =  twitter_api['tweet_id'].astype(str)

# %% [markdown]
# ### test for  twitter_api

# %%
 twitter_api.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2354 entries, 0 to 2353
# Data columns (total 3 columns):
# tweet_id     2354 non-null object
# favorites    2354 non-null int64
# retweets     2354 non-null int64
# dtypes: int64(2), object(1)
# memory usage: 55.3+ KB

# %% [markdown]
# #### now all data frames should be emerged to one

# %%
twitter1 = pd.merge(twitter_archive,  image_prediction,  on = ['tweet_id'])

twitter1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 2075 entries, 0 to 2074
# Data columns (total 29 columns):
# tweet_id                      2075 non-null object
# in_reply_to_status_id         23 non-null float64
# in_reply_to_user_id           23 non-null float64
# timestamp                     2075 non-null datetime64[ns, UTC]
# source                        2075 non-null object
# text                          2075 non-null object
# retweeted_status_id           81 non-null float64
# retweeted_status_user_id      81 non-null float64
# retweeted_status_timestamp    81 non-null object
# expanded_urls                 2075 non-null object
# rating_numerator              2075 non-null int64
# rating_denominator            2075 non-null int64
# name                          1397 non-null object
# doggo                         80 non-null object
# floofer                       8 non-null object
# pupper                        222 non-null object
# puppo                         24 non-null object
# jpg_url                       2075 non-null object
# img_num                       2075 non-null int64
# p1                            2075 non-null object
# p1_conf                       2075 non-null float64
# p1_dog                        2075 non-null bool
# p2                            2075 non-null object
# p2_conf                       2075 non-null float64
# p2_dog                        2075 non-null bool
# p3                            2075 non-null object
# p3_conf                       2075 non-null float64
# p3_dog                        2075 non-null bool
# dog_types                     2075 non-null object
# dtypes: bool(3), datetime64[ns, UTC](1), float64(7), int64(3), object(15)
# memory usage: 443.8+ KB

# %%
twitter = pd.merge(twitter1,  twitter_api,  on = ['tweet_id'])

twitter.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 2073 entries, 0 to 2072
# Data columns (total 31 columns):
# tweet_id                      2073 non-null object
# in_reply_to_status_id         23 non-null float64
# in_reply_to_user_id           23 non-null float64
# timestamp                     2073 non-null datetime64[ns, UTC]
# source                        2073 non-null object
# text                          2073 non-null object
# retweeted_status_id           79 non-null float64
# retweeted_status_user_id      79 non-null float64
# retweeted_status_timestamp    79 non-null object
# expanded_urls                 2073 non-null object
# rating_numerator              2073 non-null int64
# rating_denominator            2073 non-null int64
# name                          1396 non-null object
# doggo                         80 non-null object
# floofer                       8 non-null object
# pupper                        221 non-null object
# puppo                         24 non-null object
# jpg_url                       2073 non-null object
# img_num                       2073 non-null int64
# p1                            2073 non-null object
# p1_conf                       2073 non-null float64
# p1_dog                        2073 non-null bool
# p2                            2073 non-null object
# p2_conf                       2073 non-null float64
# p2_dog                        2073 non-null bool
# p3                            2073 non-null object
# p3_conf                       2073 non-null float64
# p3_dog                        2073 non-null bool
# dog_types                     2073 non-null object
# favorites                     2073 non-null int64
# retweets                      2073 non-null int64
# dtypes: bool(3), datetime64[ns, UTC](1), float64(7), int64(5), object(15)
# memory usage: 475.7+ KB

# %%
twitter.to_csv('twitter_archive_master.csv', 
                 index=False, encoding = 'utf-8')

# %% [markdown]
# ### Analyzing and Visualizing Data

# %%
twitter.sample(5)
# Out:
#                 tweet_id  in_reply_to_status_id  in_reply_to_user_id  \
# 1269  691483041324204033                    NaN                  NaN
# 1589  675432746517426176                    NaN                  NaN
# 1115  705442520700944385                    NaN                  NaN
# 430   808001312164028416                    NaN                  NaN
# 1543  676811746707918848                    NaN                  NaN
#
#                      timestamp  \
# 1269 2016-01-25 04:49:38+00:00
# 1589 2015-12-11 21:51:30+00:00
# 1115 2016-03-03 17:19:38+00:00
# 430  2016-12-11 17:31:39+00:00
# 1543 2015-12-15 17:11:09+00:00
#
#                                                  source  \
# 1269  <a href="http://twitter.com/download/iphone" r...
# 1589  <a href="http://twitter.com/download/iphone" r...
# 1115  <a href="http://twitter.com/download/iphone" r...
# 430   <a href="http://twitter.com/download/iphone" r...
# 1543  <a href="http://twitter.com/download/iphone" r...
#
#                                                    text  retweeted_status_id  \
# 1269  When bae says they can't go out but you see th...                  NaN
# 1589  Happy Friday. Here's some golden puppers. 12/1...                  NaN
# 1115  This is Cooper. He only wakes up to switch gea...                  NaN
# 430   This is Cooper. He likes to stick his tongue o...                  NaN
# 1543  Say hello to Penny &amp; Gizmo. They are pract...                  NaN
#
#       retweeted_status_user_id retweeted_status_timestamp  \
# 1269                       NaN                        NaN
# 1589                       NaN                        NaN
# 1115                       NaN                        NaN
# 430                        NaN                        NaN
# 1543                       NaN                        NaN
#
#                                           expanded_urls  ...  p1_dog  \
# 1269  https://twitter.com/dog_rates/status/691483041...  ...    True
# 1589  https://twitter.com/dog_rates/status/675432746...  ...    True
# 1115  https://twitter.com/dog_rates/status/705442520...  ...    True
# 430   https://twitter.com/dog_rates/status/808001312...  ...    True
# 1543  https://twitter.com/dog_rates/status/676811746...  ...    True
#
#                              p2   p2_conf p2_dog  \
# 1269    black-and-tan_coonhound  0.077420   True
# 1589           golden_retriever  0.008862   True
# 1115                     kuvasz  0.224556   True
# 430   Staffordshire_bullterrier  0.130726   True
# 1543                 Pomeranian  0.345806   True
#
#                                   p3   p3_conf p3_dog           dog_types  \
# 1269                   Gordon_setter  0.009826   True          bloodhound
# 1589                       Chihuahua  0.000694   True  Labrador_retriever
# 1115                       seat_belt  0.202100  False      Great_Pyrenees
# 430   American_Staffordshire_terrier  0.028853   True  Labrador_retriever
# 1543                  cocker_spaniel  0.060331   True           Chihuahua
#
#       favorites retweets
# 1269       2608      656
# 1589       1623      627
# 1115       4877     1859
# 430       14015     4098
# 1543       1536      469
#
# [5 rows x 31 columns]

# %%
twitter.describe()
# Out:
#        in_reply_to_status_id  in_reply_to_user_id  retweeted_status_id  \
# count           2.300000e+01         2.300000e+01         7.900000e+01
# mean            6.978112e+17         4.196984e+09         7.663364e+17
# std             4.359384e+16         0.000000e+00         5.882530e+16
# min             6.671522e+17         4.196984e+09         6.675094e+17
# 25%             6.732411e+17         4.196984e+09         7.124037e+17
# 50%             6.757073e+17         4.196984e+09         7.798343e+17
# 75%             7.031489e+17         4.196984e+09         8.068680e+17
# max             8.558181e+17         4.196984e+09         8.768508e+17
#
#        retweeted_status_user_id  rating_numerator  rating_denominator  \
# count              7.900000e+01       2073.000000         2073.000000
# mean               9.967874e+15         12.265798           10.511819
# std                8.859637e+16         40.699924            7.180517
# min                7.832140e+05          0.000000            2.000000
# 25%                4.196984e+09         10.000000           10.000000
# 50%                4.196984e+09         11.000000           10.000000
# 75%                4.196984e+09         12.000000           10.000000
# max                7.874618e+17       1776.000000          170.000000
#
#            img_num      p1_conf       p2_conf       p3_conf      favorites  \
# count  2073.000000  2073.000000  2.073000e+03  2.073000e+03    2073.000000
# mean      1.203570     0.594532  1.346665e-01  6.034005e-02    8556.718283
# std       0.561856     0.271234  1.006830e-01  5.092769e-02   12098.640994
# min       1.000000     0.044333  1.011300e-08  1.740170e-10       0.000000
# 25%       1.000000     0.364095  5.390140e-02  1.619920e-02    1674.000000
# 50%       1.000000     0.588230  1.186220e-01  4.947150e-02    3864.000000
# 75%       1.000000     0.843911  1.955730e-01  9.193000e-02   10937.000000
# max       4.000000     1.000000  4.880140e-01  2.734190e-01  132810.000000
#
#            retweets
# count   2073.000000
# mean    2976.089243
# std     5054.897526
# min       16.000000
# 25%      634.000000
# 50%     1408.000000
# 75%     3443.000000
# max    79515.000000

# %%
g = pd.DataFrame(twitter.timestamp)
fig, ax = plt.subplots(figsize=(10,5))
ax.plot_date(g,twitter.favorites, color="blue")
ax.plot_date(g,twitter.retweets, color="red")
ax.set_ylim([0,20000])
ax.set_title(' Account Popularity  the  over Time')

# Setting labels.
ax.set_ylabel('Count')
ax.set_xlabel('Time')
# Out:
# Text(0.5, 0, 'Time')

# %%
twitter.dog_types.value_counts()
# Out:
# none                    323
# golden_retriever        173
# Labrador_retriever      113
# Pembroke                 95
# Chihuahua                95
#                        ...
# Irish_wolfhound           1
# Bouvier_des_Flandres      1
# silky_terrier             1
# standard_schnauzer        1
# Scotch_terrier            1
# Name: dog_types, Length: 114, dtype: int64

# %%
df_dog_type = twitter.groupby('dog_types').filter(lambda x: len(x) >= 25)

df_dog_type['dog_types'].value_counts().plot(kind = 'bar')
plt.title('bar chart the Most Rated Dog Types')
plt.xlabel('Types of dog')
plt.ylabel('count')

fig = plt.gcf() 
fig.savefig('output.png',bbox_inches='tight');

# %%
twitter['timestamp'].apply(lambda x: x.strftime('%Y-%m')).value_counts().sort_index()
# Out:
# 2015-11    298
# 2015-12    367
# 2016-01    169
# 2016-02    111
# 2016-03    121
# 2016-04     54
# 2016-05     57
# 2016-06     81
# 2016-07     94
# 2016-08     63
# 2016-09     71
# 2016-10     71
# 2016-11     69
# 2016-12     61
# 2017-01     77
# 2017-02     68
# 2017-03     53
# 2017-04     44
# 2017-05     46
# 2017-06     46
# 2017-07     50
# 2017-08      2
# Name: timestamp, dtype: int64

# %%
selected_data = twitter['tweet_id'].groupby([twitter['timestamp'].dt.year, twitter['timestamp'].dt.month]).count()
selected_data.plot('bar')
plt.title(' mounthly tweats')
plt.xlabel('Time (Year, Month)')
plt.ylabel('Tweets count')
# Out:
# C:\Users\zakaria\Anaconda3\lib\site-packages\ipykernel_launcher.py:2: FutureWarning: `Series.plot()` should not be called with positional arguments, only keyword arguments. The order of positional arguments will change in the future. Use `Series.plot(kind='bar')` instead of `Series.plot('bar',)`.
# Text(0, 0.5, 'Tweets count')

# %%
+------++++++++++++++++\[
    +++11
    3666666666666333333333333333333333333333333333333333333333333365Series.plot(kind='bar')
]
